# %%
#Assignment #1 - Create a connection to a SQL Lite DB, print the results, and create a visualization.

# %%
# Import Dependencies
# Pandas is required
import pandas as pd
import sqlite3 as db

# %%
# Create Engine/Connection for the census_data sql lite DB
def Connect(dbName):
    return db.connect(dbName)

# %%
# Query All Records in the the census table and put the results into a DataFrame
conn = Connect("Resources/Census_Data.sqlite")
df = pd.read_sql_query("SELECT * FROM census_data", conn)
conn.close()

# %%
#Print the first 5 results in the census DataFrame
pd.options.display.max_columns = None
df.head() #default number of rows returned are always 5
# Out:
#          CityState         city state  Population  White Population  \
# 0      HOUSTON, TX      HOUSTON    TX     3061887           1775897
# 1      CHICAGO, IL      CHICAGO    IL     2702091           1318869
# 2     BROOKLYN, NY     BROOKLYN    NY     2595259           1126111
# 3  LOS ANGELES, CA  LOS ANGELES    CA     2426413           1068202
# 4        MIAMI, FL        MIAMI    FL     1820704           1361009
#
#    Black Population  Native American Population  Asian Population  \
# 0            684416                       11586            230549
# 1            843633                        7554            161478
# 2            870465                        8744            297890
# 3            324842                       15949            273829
# 4            363514                        2250             33144
#
#    Hispanic Population  Education None  Education High School  Education GED  \
# 0              1368287           54180                 387082          62520
# 1               785374           32800                 370569          50202
# 2               509243           48934                 389177          65899
# 3              1292382           62684                 280325          22924
# 4              1162711           27137                 322521          30827
#
#    Education Associates  Education Bachelors  Education Masters  \
# 0                100014               349920             138882
# 1                100972               385664             178511
# 2                107313               348413             164826
# 3                 83153               312270             104024
# 4                113990               231241              79888
#
#    Education Professional  Education Doctorate  Poverty  \
# 0                   42491                27737   633609
# 1                   54636                26956   588639
# 2                   39328                17446   597404
# 3                   40600                19436   626981
# 4                   36586                15913   338765
#
#    Employment Labor Force  Employment Unemployed  \
# 0                 1593803                 122895
# 1                 1439118                 173087
# 2                 1297832                 129667
# 3                 1273305                 141105
# 4                  935326                  91584
#
#    Employment Male Computer Engineering  \
# 0                                 67484
# 1                                 45864
# 2                                 33644
# 3                                 26989
# 4                                 20714
#
#    Employment Female Computer Engineering  Median Age  Median Male Age  \
# 0                                   22637   33.439583        32.550000
# 1                                   18209   34.526786        33.798214
# 2                                   14845   35.175676        33.367568
# 3                                   12329   35.335484        34.535484
# 4                                    6969   38.740741        37.120370
#
#    Median Female Age  Household Income  Income Per Capita  Median Gross Rent  \
# 0          34.363542       56206.50000        32239.52083         956.708333
# 1          35.141071       57735.96429        38730.83929        1119.928571
# 2          36.578378       51469.18919        28309.67568        1261.783784
# 3          36.061290       47494.58333        30073.19355        1201.766667
# 4          40.262963       51232.90741        25949.35185        1260.833333
#
#    Median Home Value        lat         lng
# 0        178233.6842  29.775734  -95.414548
# 1        264739.2857  41.867838  -87.673440
# 2        605743.2432  40.652805  -73.956528
# 3        557115.0000  34.042209 -118.303468
# 4        243279.6296  25.760268  -80.298511

# %%
# Calculate the ratio of people by state that have some level of postsecondary education vs. the total population
df['RatioPostSecEduVSPopl'] = df['Education High School']/df['Population']

# %%
# Group the results by state
dfGrouped = df.groupby(['state'])
# dfGrouped.get_group('TX')

# %%
# Print the last 5 results of the current Dataframe
# dfGrouped.tail()
df.tail()
# Out:
#                  CityState               city state  Population  \
# 994  ALTAMONTE SPRINGS, FL  ALTAMONTE SPRINGS    FL       56883
# 995        CHILLICOTHE, OH        CHILLICOTHE    OH       56783
# 996         FARMINGTON, NM         FARMINGTON    NM       56781
# 997          FAIRFIELD, CT          FAIRFIELD    CT       56704
# 998   DEARBORN HEIGHTS, MI   DEARBORN HEIGHTS    MI       56656
#
#      White Population  Black Population  Native American Population  \
# 994             42747              9599                           8
# 995             50065              3842                          27
# 996             35887               448                       14425
# 997             50515               946                           8
# 998             47746              4856                         338
#
#      Asian Population  Hispanic Population  Education None  \
# 994              1629                13925             504
# 995               398                  689             577
# 996               298                13550             425
# 997              2777                 3337             140
# 998              1108                 2371             745
#
#      Education High School  Education GED  Education Associates  \
# 994                   9336           1755                  4151
# 995                  13955           2334                  3870
# 996                   8221           2257                  3570
# 997                   5270            362                  1894
# 998                  11003           1559                  3143
#
#      Education Bachelors  Education Masters  Education Professional  \
# 994                 9539               2865                     618
# 995                 3926               1860                     371
# 996                 3886               2024                     479
# 997                11877               7063                    2127
# 998                 4741               2024                     576
#
#      Education Doctorate  Poverty  Employment Labor Force  \
# 994                  386     8040                   32405
# 995                  142     9976                   24304
# 996                  269     9687                   26574
# 997                  705     2319                   28391
# 998                  321    11254                   25456
#
#      Employment Unemployed  Employment Male Computer Engineering  \
# 994                   3062                                  1013
# 995                   2679                                   606
# 996                   1988                                   912
# 997                   1956                                  1016
# 998                   2898                                  1149
#
#      Employment Female Computer Engineering  Median Age  Median Male Age  \
# 994                                     397   40.800000        39.500000
# 995                                     356   40.400000        39.100000
# 996                                     325   34.333333        34.066667
# 997                                     367   40.150000        39.250000
# 998                                     186   38.400000        38.300000
#
#      Median Female Age  Household Income  Income Per Capita  \
# 994              42.50       49270.00000        26841.00000
# 995              42.30       43460.00000        21112.00000
# 996              35.50       48492.66667        22886.66667
# 997              41.40      119230.50000        55042.00000
# 998              38.65       45113.00000        21787.00000
#
#      Median Gross Rent  Median Home Value        lat         lng  \
# 994             1008.5        137250.0000  28.664100  -81.391002
# 995              672.0        112500.0000  39.312060  -82.957071
# 996              978.5        151933.3333  36.622898 -108.179508
# 997             1679.0        556600.0000  41.184811  -73.262036
# 998              947.5         84050.0000  42.306564  -83.274064
#
#      RatioPostSecEduVSPopl
# 994               0.164126
# 995               0.245760
# 996               0.144784
# 997               0.092939
# 998               0.194207

# %%
# Create a scatter plot showing Education vs. Median Home Value
initial = df.plot.scatter(x='Median Home Value', y='Education None', s=2, c='Red', label="Education None")
df.plot.scatter(x='Median Home Value', y='Education High School', s=2, c='Blue', ax=initial, label="Education High School")
df.plot.scatter(x='Median Home Value', y='Education GED', c='Cyan', s=2, ax=initial, label="Education GED")
df.plot.scatter(x='Median Home Value', y='Education Associates', s=2, c='Pink', ax=initial, label="Education Associates")
df.plot.scatter(x='Median Home Value', y='Education Bachelors', s=2, c='Purple', ax=initial, label="Education Bachelors")
df.plot.scatter(x='Median Home Value', y='Education Masters', s=2, c='Brown', ax=initial, label="Education Masters")
df.plot.scatter(x='Median Home Value', y='Education Professional', s=2, c='Green', ax=initial, label="Education Professional")
df.plot.scatter(x='Median Home Value', y='Education Doctorate', s=2 , c='Yellow', ax=initial, label="Education Doctorate")
initial.set_ylabel('Education')

# Export as a .png
fig = initial.get_figure()
fig.savefig('scatter_plot.png')

# Show the scatterplot
initial
# Out:
# <AxesSubplot:xlabel='Median Home Value', ylabel='Education'>

# %%
# Bonus: Is there a correlation between Total Postsecondary Ratio and Median Home Value?
# df['Median Home Value'].corr(df['RatioPostSecEduVSPopl']) - I couldnt find it

# %%
# Export the results to an Excel file after formatting the Median Home Value column
# as a dollar amount ($xx.xx).
df['Median Home Value'] = df['Median Home Value'].map("${:,.2f}".format)
df.to_excel('census_data_modified.xlsx')
